# %%
import numpy as np
import networkx as nx
from edge_fetch import edge_terrier
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import normalize
from featureAnalysis import featureSelection
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import silhouette_score
from sklearn.metrics import silhouette_samples
import matplotlib

# %%
# Initialize edgelist collector object
graph_collector = edge_terrier('/Users/paigefrank/Library/Python/3.6/bin/aws', 0, filepath='data/HNU1/ndmg_0-0-48/graphs/JHU/')
# Make a generator that yields all edgelists in filepath
filelist = graph_collector.convert_gpickle_all()
# Get a list of just the network x objects
graphList, fileList = graph_collector.getGraphs(filelist)

# %%
#Output feature matrix to a file
numFeatures = 3

#UNCOMMENT TO USE EIGENVECTOR CENTRALITY
# featureObj = featureSelection(graphList)
# X = featureObj.eigenvectorCentrality(numFeatures)
# mat = np.matrix(X, dtype = float)
# with open('outfileMat.txt','wb') as f:
#     for line in mat:
#         np.savetxt(f, line, fmt='%.2f')
# print("Feature matrix of shape", mat.shape, "outputted. Run Urerf in R now.")

#UNCOMMENT TO USE EIGEN VALUES of LAPLACIAN
# featureObj = featureSelection(graphList)
# X = featureObj.calc_eigval_feature_matrix(numFeatures)
# mat = np.matrix(X, dtype = float)
# with open('outfileMat.txt','wb') as f:
#     for line in mat:
#         np.savetxt(f, line, fmt='%.2f')
# print("Feature matrix of shape", mat.shape, "outputted. Run Urerf in R now.")

#UNCOMMENT TO USE KHOP
featureObj = featureSelection(graphList)
X = featureObj.getKhopFeatMat1(numFeatures)
mat = np.matrix(X, dtype = float)
with open('outfileMat.txt','wb') as f:
    for line in mat:
        np.savetxt(f, line, fmt='%.2f')
print("Feature matrix of shape", mat.shape, "outputted. Run Urerf in R now.")
# Out:
# [5528.120523968787, 5637.2273244147127, 2867.3750167224089, 12566.991705685617, 422.93484949832794, 1633.4663433667786, 4216.4928762541804, 1602.1424637681171, 3360.4902898550718, 1585.5080824972122, 2049.2427647714621, 2121.1000668896327, 3852.8570234113722, 2572.3563433667769, 3708.2787513935341, 3565.6093199554066, 10.481337792642154, 6990.7402006689017, 11.863311036789312, 7332.3352842809363, 3.2710256410256435, 7073.5296655518414, 3.5772129319955321, 6529.6407915273167, 565.61899665551846, 20056.825540691203, 745.00667781493837, 15633.085841694528, 3507.846811594201, 2444.7302006688974, 3496.3345707915255, 2447.7220066889613, 1894.0956075808242, 1881.0489520624308, 1578.1643701226312, 1639.5233444816051, 2468.2505574135985, 1533.5349386845046, 2622.2600222965439, 1586.2438684503891, 3263.3472798216294, 2056.2943143812709, 3054.6878483835021, 2025.2916276477149, 550.79661092530625, 2945.3526309921967, 257.79424749163854, 2684.2333444816068, 3047.5206243032321, 1531.9336789297672, 2825.3026086956515, 1539.218049052397, 4186.7499999999991, 1593.6827647714601, 3789.9523299888529, 1572.0365105908579, 1262.4206354515043, 2287.3141025641053, 1466.5429654403558, 2559.7255741360095, 1248.0238461538465, 3711.0732998885169, 1359.1658751393536, 3640.2646153846181, 3805.6652842809376, 1874.5405908584166, 3333.7098216276454, 1945.693143812711, 3763.3102675585269, 1634.7690523968788, 4349.1391192865103, 1624.9210256410265, 1295.864648829431, 2385.3447491638785, 1022.0590858416944, 2351.2137792642143, 1288.3676588628757, 2897.4073132664444, 1159.7820624303235, 3274.7892530657737, 4923.1176254180591, 1880.9866109253071, 4206.3391192865083, 1956.2296544035673, 1026.7284169453731, 2757.7169565217387, 1323.0754069119287, 2785.5260200668913, 420.77470457079158, 6109.9830992196212, 871.35433667781433, 7292.3538350055669, 1277.7397881828308, 2016.9116945373476, 1073.127491638797, 1983.2045039018965]
# Feature matrix of shape (300, 3) outputted. Run Urerf in R now.

# %%
matrix = open('outfileSimMat.txt').read()
matrix = [item.split() for item in matrix.split('\n')[:-1]]
inputMat = np.matrix(matrix, dtype = float)

# %%
#collect correct labels:
correctLabels = []
for item in fileList:
    correctLabels.append(float(item[4:11]) - 25426.0)

# %%
#Graph the data if the features are less than 3 dimensions


if (numFeatures ==2):
    fig = plt.figure(3, figsize=(10, 10))
    fig.suptitle("Visualization of Clustered HBN Data (dwi)", fontsize=20)

    ax = plt.Axes(fig, rect=[0, 0, .5, .5])
    z = list(correctLabels)
    N = len(mat[:,1])
    x = [mat[:,0]]
    y = [mat[:,1]]
    #labels = np.ones((0,97))
    cmap = matplotlib.cm.get_cmap('plasma')
    normalize = matplotlib.colors.Normalize(vmin=min(z), vmax=max(z))
    colors = [cmap(normalize(value)) for value in z]
    plt.scatter(x, y, color = colors)

    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    
if (numFeatures ==3):
    fig = plt.figure(3, figsize=(10, 10))
    fig.suptitle("Visualization of Clustered HBN Data (dwi)", fontsize=20)
    ax = Axes3D(fig, rect=[0, 0, .5, .5], elev=40, azim=150)
    ax.scatter(mat[:, 0], mat[:, 1], mat[:, 2], c=correctLabels, cmap = "plasma")
    ax.set_xlabel('Feature 1')
    ax.set_ylabel('Feature 2')
    ax.set_zlabel('Feature 3')

# %%
#Cluster with mini Batch K Means for multiple parameters
setInput = mat #set to mat for feature matrix or input mat for Urerf matrix
maxClusters = 0
maxSize = 0
maxSil = 0
for i in range(2, 50):
    #vary the cluster number
    clust = i
    for j in range(1, 5):
        #vary the batch size
        batchSize = 50 + (j * 20)
        mb = MiniBatchKMeans(n_clusters = clust, batch_size = batchSize).fit(setInput)
        cluster_centers_ = mb.cluster_centers_
        labels = mb.labels_
        ss = silhouette_score(inputMat, labels)
        print('|BatchSize |% 1.2f' %  batchSize, "| Clusters | % 1.1f" % clust, "| Silhouette | % 1.3f" % ss, "|")
        
        #capture max preproc and damping
        if (ss > maxSil):
            maxClusters = clust
            maxSize = batchSize
            maxSil = ss
print("Best Batch Size:", maxSize, "Best Num Clusters:", maxClusters)
# Out:
# |BatchSize | 70.00 | Clusters |  2.0 | Silhouette |  0.020 |
# |BatchSize | 90.00 | Clusters |  2.0 | Silhouette |  0.020 |
# |BatchSize | 110.00 | Clusters |  2.0 | Silhouette |  0.020 |
# |BatchSize | 130.00 | Clusters |  2.0 | Silhouette |  0.020 |
# |BatchSize | 70.00 | Clusters |  3.0 | Silhouette |  0.021 |
# |BatchSize | 90.00 | Clusters |  3.0 | Silhouette |  0.022 |
# |BatchSize | 110.00 | Clusters |  3.0 | Silhouette |  0.022 |
# |BatchSize | 130.00 | Clusters |  3.0 | Silhouette |  0.022 |
# |BatchSize | 70.00 | Clusters |  4.0 | Silhouette |  0.027 |
# |BatchSize | 90.00 | Clusters |  4.0 | Silhouette |  0.028 |
# |BatchSize | 110.00 | Clusters |  4.0 | Silhouette |  0.026 |
# |BatchSize | 130.00 | Clusters |  4.0 | Silhouette |  0.027 |
# |BatchSize | 70.00 | Clusters |  5.0 | Silhouette |  0.033 |
# |BatchSize | 90.00 | Clusters |  5.0 | Silhouette |  0.033 |
# |BatchSize | 110.00 | Clusters |  5.0 | Silhouette |  0.035 |
# |BatchSize | 130.00 | Clusters |  5.0 | Silhouette |  0.033 |
# |BatchSize | 70.00 | Clusters |  6.0 | Silhouette |  0.037 |
# |BatchSize | 90.00 | Clusters |  6.0 | Silhouette |  0.034 |
# |BatchSize | 110.00 | Clusters |  6.0 | Silhouette |  0.035 |
# |BatchSize | 130.00 | Clusters |  6.0 | Silhouette |  0.033 |
# |BatchSize | 70.00 | Clusters |  7.0 | Silhouette |  0.038 |
# |BatchSize | 90.00 | Clusters |  7.0 | Silhouette |  0.042 |
# |BatchSize | 110.00 | Clusters |  7.0 | Silhouette |  0.030 |
# |BatchSize | 130.00 | Clusters |  7.0 | Silhouette |  0.045 |
# |BatchSize | 70.00 | Clusters |  8.0 | Silhouette |  0.036 |
# |BatchSize | 90.00 | Clusters |  8.0 | Silhouette |  0.041 |
# |BatchSize | 110.00 | Clusters |  8.0 | Silhouette |  0.043 |
# |BatchSize | 130.00 | Clusters |  8.0 | Silhouette |  0.039 |
# |BatchSize | 70.00 | Clusters |  9.0 | Silhouette |  0.046 |
# |BatchSize | 90.00 | Clusters |  9.0 | Silhouette |  0.037 |
# |BatchSize | 110.00 | Clusters |  9.0 | Silhouette |  0.049 |
# |BatchSize | 130.00 | Clusters |  9.0 | Silhouette |  0.044 |
# |BatchSize | 70.00 | Clusters |  10.0 | Silhouette |  0.045 |
# |BatchSize | 90.00 | Clusters |  10.0 | Silhouette |  0.049 |
# |BatchSize | 110.00 | Clusters |  10.0 | Silhouette |  0.048 |
# |BatchSize | 130.00 | Clusters |  10.0 | Silhouette |  0.052 |
# |BatchSize | 70.00 | Clusters |  11.0 | Silhouette |  0.053 |
# |BatchSize | 90.00 | Clusters |  11.0 | Silhouette |  0.053 |
# |BatchSize | 110.00 | Clusters |  11.0 | Silhouette |  0.049 |
# |BatchSize | 130.00 | Clusters |  11.0 | Silhouette |  0.055 |
# |BatchSize | 70.00 | Clusters |  12.0 | Silhouette |  0.052 |
# |BatchSize | 90.00 | Clusters |  12.0 | Silhouette |  0.054 |
# |BatchSize | 110.00 | Clusters |  12.0 | Silhouette |  0.055 |
# |BatchSize | 130.00 | Clusters |  12.0 | Silhouette |  0.051 |
# |BatchSize | 70.00 | Clusters |  13.0 | Silhouette |  0.060 |
# |BatchSize | 90.00 | Clusters |  13.0 | Silhouette |  0.055 |
# |BatchSize | 110.00 | Clusters |  13.0 | Silhouette |  0.058 |
# |BatchSize | 130.00 | Clusters |  13.0 | Silhouette |  0.059 |
# |BatchSize | 70.00 | Clusters |  14.0 | Silhouette |  0.055 |
# |BatchSize | 90.00 | Clusters |  14.0 | Silhouette |  0.061 |
# |BatchSize | 110.00 | Clusters |  14.0 | Silhouette |  0.064 |
# |BatchSize | 130.00 | Clusters |  14.0 | Silhouette |  0.057 |
# |BatchSize | 70.00 | Clusters |  15.0 | Silhouette |  0.054 |
# |BatchSize | 90.00 | Clusters |  15.0 | Silhouette |  0.063 |
# |BatchSize | 110.00 | Clusters |  15.0 | Silhouette |  0.061 |
# |BatchSize | 130.00 | Clusters |  15.0 | Silhouette |  0.062 |
# |BatchSize | 70.00 | Clusters |  16.0 | Silhouette |  0.064 |
# |BatchSize | 90.00 | Clusters |  16.0 | Silhouette |  0.059 |
# |BatchSize | 110.00 | Clusters |  16.0 | Silhouette |  0.059 |
# |BatchSize | 130.00 | Clusters |  16.0 | Silhouette |  0.059 |
# |BatchSize | 70.00 | Clusters |  17.0 | Silhouette |  0.066 |
# |BatchSize | 90.00 | Clusters |  17.0 | Silhouette |  0.064 |
# |BatchSize | 110.00 | Clusters |  17.0 | Silhouette |  0.061 |
# |BatchSize | 130.00 | Clusters |  17.0 | Silhouette |  0.061 |
# |BatchSize | 70.00 | Clusters |  18.0 | Silhouette |  0.063 |
# |BatchSize | 90.00 | Clusters |  18.0 | Silhouette |  0.060 |
# |BatchSize | 110.00 | Clusters |  18.0 | Silhouette |  0.062 |
# |BatchSize | 130.00 | Clusters |  18.0 | Silhouette |  0.064 |
# |BatchSize | 70.00 | Clusters |  19.0 | Silhouette |  0.066 |
# |BatchSize | 90.00 | Clusters |  19.0 | Silhouette |  0.067 |
# |BatchSize | 110.00 | Clusters |  19.0 | Silhouette |  0.063 |
# |BatchSize | 130.00 | Clusters |  19.0 | Silhouette |  0.071 |
# |BatchSize | 70.00 | Clusters |  20.0 | Silhouette |  0.067 |
# |BatchSize | 90.00 | Clusters |  20.0 | Silhouette |  0.071 |
# |BatchSize | 110.00 | Clusters |  20.0 | Silhouette |  0.063 |
# |BatchSize | 130.00 | Clusters |  20.0 | Silhouette |  0.067 |
# |BatchSize | 70.00 | Clusters |  21.0 | Silhouette |  0.068 |
# |BatchSize | 90.00 | Clusters |  21.0 | Silhouette |  0.065 |
# |BatchSize | 110.00 | Clusters |  21.0 | Silhouette |  0.065 |
# |BatchSize | 130.00 | Clusters |  21.0 | Silhouette |  0.064 |
# |BatchSize | 70.00 | Clusters |  22.0 | Silhouette |  0.069 |
# |BatchSize | 90.00 | Clusters |  22.0 | Silhouette |  0.063 |
# |BatchSize | 110.00 | Clusters |  22.0 | Silhouette |  0.072 |
# |BatchSize | 130.00 | Clusters |  22.0 | Silhouette |  0.064 |
# |BatchSize | 70.00 | Clusters |  23.0 | Silhouette |  0.068 |
# |BatchSize | 90.00 | Clusters |  23.0 | Silhouette |  0.070 |
# |BatchSize | 110.00 | Clusters |  23.0 | Silhouette |  0.070 |
# |BatchSize | 130.00 | Clusters |  23.0 | Silhouette |  0.073 |
# |BatchSize | 70.00 | Clusters |  24.0 | Silhouette |  0.070 |
# |BatchSize | 90.00 | Clusters |  24.0 | Silhouette |  0.060 |
# |BatchSize | 110.00 | Clusters |  24.0 | Silhouette |  0.070 |
# |BatchSize | 130.00 | Clusters |  24.0 | Silhouette |  0.065 |
# |BatchSize | 70.00 | Clusters |  25.0 | Silhouette |  0.069 |
# |BatchSize | 90.00 | Clusters |  25.0 | Silhouette |  0.075 |
# |BatchSize | 110.00 | Clusters |  25.0 | Silhouette |  0.071 |
# |BatchSize | 130.00 | Clusters |  25.0 | Silhouette |  0.073 |
# |BatchSize | 70.00 | Clusters |  26.0 | Silhouette |  0.062 |
# |BatchSize | 90.00 | Clusters |  26.0 | Silhouette |  0.055 |
# |BatchSize | 110.00 | Clusters |  26.0 | Silhouette |  0.071 |
# |BatchSize | 130.00 | Clusters |  26.0 | Silhouette |  0.071 |
# |BatchSize | 70.00 | Clusters |  27.0 | Silhouette |  0.066 |
# |BatchSize | 90.00 | Clusters |  27.0 | Silhouette |  0.065 |
# |BatchSize | 110.00 | Clusters |  27.0 | Silhouette |  0.071 |
# |BatchSize | 130.00 | Clusters |  27.0 | Silhouette |  0.071 |
# |BatchSize | 70.00 | Clusters |  28.0 | Silhouette |  0.074 |
# |BatchSize | 90.00 | Clusters |  28.0 | Silhouette |  0.066 |
# |BatchSize | 110.00 | Clusters |  28.0 | Silhouette |  0.071 |
# |BatchSize | 130.00 | Clusters |  28.0 | Silhouette |  0.061 |
# |BatchSize | 70.00 | Clusters |  29.0 | Silhouette |  0.061 |
# |BatchSize | 90.00 | Clusters |  29.0 | Silhouette |  0.069 |
# |BatchSize | 110.00 | Clusters |  29.0 | Silhouette |  0.073 |
# |BatchSize | 130.00 | Clusters |  29.0 | Silhouette |  0.076 |
# |BatchSize | 70.00 | Clusters |  30.0 | Silhouette |  0.062 |
# |BatchSize | 90.00 | Clusters |  30.0 | Silhouette |  0.067 |
# |BatchSize | 110.00 | Clusters |  30.0 | Silhouette |  0.069 |
# |BatchSize | 130.00 | Clusters |  30.0 | Silhouette |  0.079 |
# |BatchSize | 70.00 | Clusters |  31.0 | Silhouette |  0.070 |
# |BatchSize | 90.00 | Clusters |  31.0 | Silhouette |  0.068 |
# |BatchSize | 110.00 | Clusters |  31.0 | Silhouette |  0.069 |
# |BatchSize | 130.00 | Clusters |  31.0 | Silhouette |  0.078 |
# |BatchSize | 70.00 | Clusters |  32.0 | Silhouette |  0.069 |
# |BatchSize | 90.00 | Clusters |  32.0 | Silhouette |  0.067 |
# |BatchSize | 110.00 | Clusters |  32.0 | Silhouette |  0.075 |
# |BatchSize | 130.00 | Clusters |  32.0 | Silhouette |  0.070 |
# |BatchSize | 70.00 | Clusters |  33.0 | Silhouette |  0.064 |
# |BatchSize | 90.00 | Clusters |  33.0 | Silhouette |  0.066 |
# |BatchSize | 110.00 | Clusters |  33.0 | Silhouette |  0.064 |
# |BatchSize | 130.00 | Clusters |  33.0 | Silhouette |  0.073 |
# |BatchSize | 70.00 | Clusters |  34.0 | Silhouette |  0.076 |
# |BatchSize | 90.00 | Clusters |  34.0 | Silhouette |  0.067 |
# |BatchSize | 110.00 | Clusters |  34.0 | Silhouette |  0.070 |
# |BatchSize | 130.00 | Clusters |  34.0 | Silhouette |  0.066 |
# |BatchSize | 70.00 | Clusters |  35.0 | Silhouette |  0.062 |
# |BatchSize | 90.00 | Clusters |  35.0 | Silhouette |  0.069 |
# |BatchSize | 110.00 | Clusters |  35.0 | Silhouette |  0.072 |
# |BatchSize | 130.00 | Clusters |  35.0 | Silhouette |  0.075 |
# |BatchSize | 70.00 | Clusters |  36.0 | Silhouette |  0.075 |
# |BatchSize | 90.00 | Clusters |  36.0 | Silhouette |  0.071 |
# |BatchSize | 110.00 | Clusters |  36.0 | Silhouette |  0.072 |
# |BatchSize | 130.00 | Clusters |  36.0 | Silhouette |  0.070 |
# |BatchSize | 70.00 | Clusters |  37.0 | Silhouette |  0.066 |
# |BatchSize | 90.00 | Clusters |  37.0 | Silhouette |  0.069 |
# |BatchSize | 110.00 | Clusters |  37.0 | Silhouette |  0.075 |
# |BatchSize | 130.00 | Clusters |  37.0 | Silhouette |  0.073 |
# |BatchSize | 70.00 | Clusters |  38.0 | Silhouette |  0.078 |
# |BatchSize | 90.00 | Clusters |  38.0 | Silhouette |  0.070 |
# |BatchSize | 110.00 | Clusters |  38.0 | Silhouette |  0.073 |
# |BatchSize | 130.00 | Clusters |  38.0 | Silhouette |  0.070 |
# |BatchSize | 70.00 | Clusters |  39.0 | Silhouette |  0.069 |
# |BatchSize | 90.00 | Clusters |  39.0 | Silhouette |  0.067 |
# |BatchSize | 110.00 | Clusters |  39.0 | Silhouette |  0.074 |
# |BatchSize | 130.00 | Clusters |  39.0 | Silhouette |  0.069 |
# |BatchSize | 70.00 | Clusters |  40.0 | Silhouette |  0.070 |
# |BatchSize | 90.00 | Clusters |  40.0 | Silhouette |  0.075 |
# |BatchSize | 110.00 | Clusters |  40.0 | Silhouette |  0.072 |
# |BatchSize | 130.00 | Clusters |  40.0 | Silhouette |  0.079 |
# |BatchSize | 70.00 | Clusters |  41.0 | Silhouette |  0.073 |
# |BatchSize | 90.00 | Clusters |  41.0 | Silhouette |  0.068 |
# |BatchSize | 110.00 | Clusters |  41.0 | Silhouette |  0.070 |
# |BatchSize | 130.00 | Clusters |  41.0 | Silhouette |  0.078 |
# |BatchSize | 70.00 | Clusters |  42.0 | Silhouette |  0.064 |
# |BatchSize | 90.00 | Clusters |  42.0 | Silhouette |  0.066 |
# |BatchSize | 110.00 | Clusters |  42.0 | Silhouette |  0.066 |
# |BatchSize | 130.00 | Clusters |  42.0 | Silhouette |  0.073 |
# |BatchSize | 70.00 | Clusters |  43.0 | Silhouette |  0.076 |
# |BatchSize | 90.00 | Clusters |  43.0 | Silhouette |  0.067 |
# |BatchSize | 110.00 | Clusters |  43.0 | Silhouette |  0.065 |
# |BatchSize | 130.00 | Clusters |  43.0 | Silhouette |  0.075 |
# |BatchSize | 70.00 | Clusters |  44.0 | Silhouette |  0.069 |
# |BatchSize | 90.00 | Clusters |  44.0 | Silhouette |  0.070 |
# |BatchSize | 110.00 | Clusters |  44.0 | Silhouette |  0.073 |
# |BatchSize | 130.00 | Clusters |  44.0 | Silhouette |  0.072 |
# |BatchSize | 70.00 | Clusters |  45.0 | Silhouette |  0.073 |
# |BatchSize | 90.00 | Clusters |  45.0 | Silhouette |  0.069 |
# |BatchSize | 110.00 | Clusters |  45.0 | Silhouette |  0.074 |
# |BatchSize | 130.00 | Clusters |  45.0 | Silhouette |  0.079 |
# |BatchSize | 70.00 | Clusters |  46.0 | Silhouette |  0.070 |
# |BatchSize | 90.00 | Clusters |  46.0 | Silhouette |  0.072 |
# |BatchSize | 110.00 | Clusters |  46.0 | Silhouette |  0.077 |
# |BatchSize | 130.00 | Clusters |  46.0 | Silhouette |  0.078 |
# |BatchSize | 70.00 | Clusters |  47.0 | Silhouette |  0.073 |
# |BatchSize | 90.00 | Clusters |  47.0 | Silhouette |  0.075 |
# |BatchSize | 110.00 | Clusters |  47.0 | Silhouette |  0.081 |
# |BatchSize | 130.00 | Clusters |  47.0 | Silhouette |  0.077 |
# |BatchSize | 70.00 | Clusters |  48.0 | Silhouette |  0.070 |
# |BatchSize | 90.00 | Clusters |  48.0 | Silhouette |  0.065 |
# |BatchSize | 110.00 | Clusters |  48.0 | Silhouette |  0.072 |
# |BatchSize | 130.00 | Clusters |  48.0 | Silhouette |  0.075 |
# |BatchSize | 70.00 | Clusters |  49.0 | Silhouette |  0.070 |
# |BatchSize | 90.00 | Clusters |  49.0 | Silhouette |  0.071 |
# |BatchSize | 110.00 | Clusters |  49.0 | Silhouette |  0.082 |
# |BatchSize | 130.00 | Clusters |  49.0 | Silhouette |  0.074 |
# Best Batch Size: 110 Best Num Clusters: 49

# %%
#isolate best clustering output and create a sorted similarity matrix
mb = MiniBatchKMeans(n_clusters= maxClusters, batch_size = maxSize).fit(inputMat)
cluster_centers_ = mb.cluster_centers_
labels = mb.labels_
n_clusters = len(cluster_centers_)

#create a dictionary of labels and subjects
nodeDict = dict(enumerate(labels))

#sort the subjects so that they are grouped by cluster label
s = sorted(nodeDict, key=nodeDict.get)
#create a sorted similarity matrix
sortedSimMat = np.empty((len(s), len(s)))
for i in range(0, len(s)):
    node = s[i]
    for j in range(0,len(s)):
        node2 = s[j]
        sortedSimMat[i][j] = inputMat[node, node2]

# %%
#create a heat map of the sorted similarity matrix
plt.figure(1)
im = plt.imshow(sortedSimMat, cmap='hot', interpolation='nearest')
cbar = plt.colorbar(im) 
plt.xlabel('Graphs')
plt.ylabel('Graphs')
plt.title("Clustered Similarity Matrix - \nHNU1 data dwi samples")
plt.show()

# %%
#create a heat map of the sorted similarity matrix
plt.figure(2)
im = plt.imshow(inputMat, cmap='hot', interpolation='nearest')
cbar = plt.colorbar(im) 
plt.xlabel('Graphs')
plt.ylabel('Graphs')
plt.title("Uref Similarity matrix - \nHNU1 data dwi samples")
plt.axis('off')
plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(labels, correctLabels)
# Out:
# 0.056666666666666664

# %%
#Create a plot of the clusters color-coded as such

if (numFeatures ==2):
    fig = plt.figure(3, figsize=(10, 10))
    ax = plt.Axes(fig, rect=[0, 0, .5, .5])
    z = list(labels)
    N = len(mat[:,1])
    x = [mat[:,0]]
    y = [mat[:,1]]
    #labels = np.ones((0,97))
    cmap = matplotlib.cm.get_cmap('plasma')
    normalize = matplotlib.colors.Normalize(vmin=min(z), vmax=max(z))
    colors = [cmap(normalize(value)) for value in z]
    plt.scatter(x, y, color = colors)

    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    
if (numFeatures ==3):
    fig = plt.figure(4, figsize=(10, 10))
    ax = Axes3D(fig, rect=[0, 0, .5, .5], elev=40, azim=150)
    ax.scatter(mat[:, 0], mat[:, 1], mat[:, 2], c=labels, cmap = "plasma")
    ax.set_xlabel('Feature 1')
    ax.set_ylabel('Feature 2')
    ax.set_zlabel('Feature 3')
